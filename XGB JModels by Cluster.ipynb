# %% [markdown]
# # Cluster Approach
#
# This is the same XGB vJ approach but with a plot twist!
#
# We are breaking the datasets into Clusters and we are going to train a model per cluster.
#
# To see how we computed the cluster please refer to Pablo's code on H2O

# %%
predict_w11 = True #I'm going to use this variable to know when to use w10 for training
dataset_file = 'jorge_dataset_modifiedwPred.csv'

# %% [markdown]
# ### Imports

# %%
import os

mingw_path = 'C:\\Program Files\\mingw-w64\\x86_64-5.3.0-posix-seh-rt_v4-rev0\\mingw64\\bin'

os.environ['PATH'] = mingw_path + ';' + os.environ['PATH']

import xgboost as xgb
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Anaconda\lib\site-packages\pandas\computation\__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
import pandas as pd
import numpy as np
import re 
import os
import time
from IPython.display import display
import matplotlib.pyplot as plt
from sklearn.cross_validation import LabelKFold
from sklearn.grid_search import GridSearchCV
import seaborn as sns
# %matplotlib inline

# %%
clusters_by_ClientDemand = pd.read_csv("h2o-clustByDem_Cliente_ID.csv")

# Load computed Dataset
def load_dataset(folder = ''):
    
    
    filename = dataset_file
    filepath = os.path.join(folder,filename)        
    
    df_train = pd.read_csv(filepath, 
                           usecols = {'Producto_ID',
                                     'Semana',
                                     'Cliente_ID',
                                     'Agencia_ID',
                                     'Canal_ID',
                                     'Ruta_SAK',
                                     'ZipCode',      
                                     'week_ct','brand',
                                     'Log_Target_mean_lag1','Log_Target_mean_lag2',
                                     'Log_Target_mean_lag3','Log_Target_mean_lag4',
                                     'Lags_sum','Qty_Ruta_SAK_Bin','num_prod','num_prod_uni',
                                     'id',
                                     'Last_per_Ruta_SAK','Last_per_Cliente_ID',                                      
                                     'Demanda_uni_equil'},
                           dtype  = {'Producto_ID':'int32',
                                     'Semana':'int8',
                                     'Cliente_ID':'int32',
                                     'Agencia_ID':'uint16',
                                     'Canal_ID':'int8',
                                     'Ruta_SAK':'int32',
                                     'ZipCode':'int16',  
                                     'id':'int32',
                                     'week_ct':'int8',
                                     'Log_Target_mean_lag1':'float32','Log_Target_mean_lag2':'float32',
                                     'Log_Target_mean_lag3':'float32','Log_Target_mean_lag4':'float32',
                                     'Lags_sum':'float32','Qty_Ruta_SAK_Bin':'float32','num_prod':'float32','num_prod_uni':'float32',                                     
                                     'Last_per_Ruta_SAK':'float32','Last_per_Cliente_ID':'float32',
                                     'Demanda_uni_equil':'float32'})
    
    
    return df_train

df = load_dataset()

# %%
print df.Cliente_ID.unique().shape[0], clusters_by_ClientDemand.Cliente_ID.unique().shape[0]
# Out:
# 888272 842629

# %%
print df.Cliente_ID.unique().shape[0] - clusters_by_ClientDemand.Cliente_ID.unique().shape[0]
# Out:
# 45643

# %%
df = df.merge(clusters_by_ClientDemand, on='Cliente_ID',how='left')

# %%
df.dtypes
# Out:
# Agencia_ID               uint16
# Canal_ID                   int8
# Cliente_ID                int32
# Demanda_uni_equil       float32
# Producto_ID               int32
# Ruta_SAK                  int32
# Semana                     int8
# ZipCode                   int16
# id                        int32
# Last_per_Cliente_ID     float32
# Last_per_Ruta_SAK       float32
# week_ct                    int8
# Log_Target_mean_lag1    float32
# Log_Target_mean_lag2    float32
# Log_Target_mean_lag3    float32
# Log_Target_mean_lag4    float32
# Lags_sum                float32
# brand                   float64
# Qty_Ruta_SAK_Bin        float32
# num_prod                float32
# num_prod_uni            float32
# Cliente_ID_clust_ID     float64
# dtype: object

# %% [markdown]
# I don't know why but I have more Cliente_ID than Pablo's Cluster ID table

# %% [markdown]
# Now, For each Cluster I want to train using my best_param found in my XGB vJ Models notebook

# %%
validation = 9 

if predict_w11:
    validation = 10
    
df.Demanda_uni_equil[df.Demanda_uni_equil < 0] = 0
df_validation = df[df.Semana == validation]
df_train = df[(df.Semana != 3) & (df.Semana < validation)]
df_test = df[df.Semana > validation]
del df

# %%
best_param = {'max_depth':[10], 
        'n_estimators':[100] ,
        'learning_rate':[0.1],         
         'subsample': [0.5],
         #'reg_alpha':[0,1], #L2 term
         #'reg_lambda':[0,1]#, #L1 tem            
         #'silent': [False]
        }

param = {'max_depth':[10,6], 
        'n_estimators':[50] ,
        'learning_rate':[0.1,0.05],         
         'subsample': [0.5,1],
         #'reg_alpha':[0,1], #L2 term
         #'reg_lambda':[0,1]#, #L1 tem            
         #'silent': [False]
        }

# %%
# Remove Columns that are not features 
#drop_columns = ['id','Semana','Demanda_uni_equil','DemandaAgencia_ID','DemandaCanal_ID','DemandaRuta_SAK','DemandaZipCode']
drop_columns = ['id','Semana','Demanda_uni_equil']
features = df_train.drop(drop_columns,axis=1).columns
print features
# Out:
# Index([u'Agencia_ID', u'Canal_ID', u'Cliente_ID', u'Producto_ID', u'Ruta_SAK',
#        u'ZipCode', u'Last_per_Cliente_ID', u'Last_per_Ruta_SAK', u'week_ct',
#        u'Log_Target_mean_lag1', u'Log_Target_mean_lag2',
#        u'Log_Target_mean_lag3', u'Log_Target_mean_lag4', u'Lags_sum', u'brand',
#        u'Qty_Ruta_SAK_Bin', u'num_prod', u'num_prod_uni',
#        u'Cliente_ID_clust_ID'],
#       dtype='object')

# %%
Semana = df_train.Semana
X_train = df_train[features]

X_valid = df_validation[features]

X_test = df_test[features]

Y_train = df_train['Demanda_uni_equil']
Y_test = df_test['Demanda_uni_equil']
Y_valid = df_validation['Demanda_uni_equil']

# %%
X_train[X_train.Cliente_ID_clust_ID == 174].head()
# Out:
#       Agencia_ID  Canal_ID  Cliente_ID  Producto_ID  Ruta_SAK  ZipCode  \
# 9584        1110         7     2136383         1250      3303     2008
# 9585        1110         7     2136383          325      3303     2008
# 9586        1110         7     2136383         1242      3303     2008
# 9587        1110         7     2136383         1250      3303     2008
# 9588        1110         7     2136383         5310      3303     2008
#
#       Last_per_Cliente_ID  Last_per_Ruta_SAK  week_ct  Log_Target_mean_lag1  \
# 9584             1.945910           2.013359        0              0.000000
# 9585             0.693147           1.294880        1              0.000000
# 9586             2.302585           1.718077        1              0.000000
# 9587             1.098612           2.006562        1              1.098612
# 9588             1.945910           2.273084        1              0.000000
#
#       Log_Target_mean_lag2  Log_Target_mean_lag3  Log_Target_mean_lag4  \
# 9584                   0.0                   0.0                   0.0
# 9585                   0.0                   0.0                   0.0
# 9586                   0.0                   0.0                   0.0
# 9587                   0.0                   0.0                   0.0
# 9588                   0.0                   0.0                   0.0
#
#       Lags_sum  brand  Qty_Ruta_SAK_Bin  num_prod  num_prod_uni  \
# 9584  0.000000    2.0               1.0       1.0           1.0
# 9585  0.000000   32.0               1.0       9.0           9.0
# 9586  0.000000    2.0               1.0       9.0           9.0
# 9587  1.098612    2.0               1.0       9.0           9.0
# 9588  0.000000   14.0               1.0       9.0           9.0
#
#       Cliente_ID_clust_ID
# 9584                174.0
# 9585                174.0
# 9586                174.0
# 9587                174.0
# 9588                174.0

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.grid_search import ParameterGrid

sick_clusters = []
val_pred = pd.DataFrame()

for cluster in clusters_by_ClientDemand.Cliente_ID_clust_ID.unique():
    
    print "Cluster :", cluster
    for g in ParameterGrid(best_param):
        start = time.time()
        
        x_train = X_train[X_train.Cliente_ID_clust_ID == cluster]
        y_train = df_train['Demanda_uni_equil'][df_train.Cliente_ID_clust_ID == cluster]
        
        x_valid = X_valid[X_valid.Cliente_ID_clust_ID == cluster]
        y_valid = df_validation['Demanda_uni_equil'][df_validation.Cliente_ID_clust_ID == cluster]

        grid_gbm = xgb.XGBRegressor(**g)
        grid_gbm.fit(x_train, y_train,eval_set=[(x_valid,y_valid)] ,eval_metric='rmse',verbose='False',early_stopping_rounds=10)
        
        score = grid_gbm.evals_result_.values()[-1].values()[-1][-1]
        print "Score for this combination: ", score
        
        tmp = pd.DataFrame()
        tmp['target'] = y_valid
        tmp['pred'] =  grid_gbm.predict(x_valid)
        tmp['cluster'] = cluster
        val_pred =pd.concat([val_pred,tmp], ignore_index=True)
        
        if(score > 0.5):
            sick_clusters.append((cluster,score))

        print("total time taken this loop: ", time.time() - start)

    #pred_train = gbm.predict(X_train)
    #pred_val = gbm.predict(X_valid)

    #print "R2 Train = ",r2_score(np.float64(Y_train),np.float64(pred_train))
    #print "RMSE Train", np.sqrt(mean_squared_error(np.float64(Y_train),np.float64(pred_train)))
    
    #print "R2 Validation= ",r2_score(np.float64(Y_valid),np.float64(pred_val))
    #print "RMSE Validation ", np.sqrt(mean_squared_error(np.float64(Y_valid),np.float64(pred_val)))
# Out:
# Cluster : 176
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [24]	validation_0-rmse:0.687273
#
# Score for this combination:  0.700155
# ('total time taken this loop: ', 19.874000072479248)
# Cluster : 307
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [28]	validation_0-rmse:0.738238
#
# Score for this combination:  0.758507
# ('total time taken this loop: ', 1.7349998950958252)
# Cluster : 139
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [25]	validation_0-rmse:0.798207
#
# Score for this combination:  0.815009
# ('total time taken this loop: ', 4.0940001010894775)
# Cluster : 19
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [20]	validation_0-rmse:1.40199
#
# Score for this combination:  1.428401
# ('total time taken this loop: ', 0.4679999351501465)
# Cluster : 335
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [20]	validation_0-rmse:0.848172
#
# Score for this combination:  0.868394
# ('total time taken this loop: ', 3.687999963760376)
# Cluster : 284
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:1.33042
#
# Score for this combination:  1.406249
# ('total time taken this loop: ', 0.6410000324249268)
# Cluster : 17
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [17]	validation_0-rmse:0.919983
#
# Score for this combination:  0.952924
# ('total time taken this loop: ', 3.0309998989105225)
# Cluster : 215
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [2]	validation_0-rmse:0.899484
#
# Score for this combination:  1.049607
# ('total time taken this loop: ', 0.3900001049041748)
# Cluster : 295
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:1.52094
#
# Score for this combination:  1.611442
# ('total time taken this loop: ', 0.5950000286102295)
# Cluster : 321
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.561596
#
# Score for this combination:  0.57695
# ('total time taken this loop: ', 4.95199990272522)
# Cluster : 118
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	validation_0-rmse:0.480393
#
# Score for this combination:  0.491967
# ('total time taken this loop: ', 2.3440001010894775)
# Cluster : 169
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.486528
#
# Score for this combination:  0.506501
# ('total time taken this loop: ', 1.4219999313354492)
# Cluster : 97
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.494375
#
# Score for this combination:  0.522045
# ('total time taken this loop: ', 0.9690001010894775)
# Cluster : 197
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.601083
#
# Score for this combination:  0.622291
# ('total time taken this loop: ', 6.234999895095825)
# Cluster : 38
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.827182
#
# Score for this combination:  0.91493
# ('total time taken this loop: ', 1.2339999675750732)
# Cluster : 222
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [16]	validation_0-rmse:0.680544
#
# Score for this combination:  0.712806
# ('total time taken this loop: ', 0.7599999904632568)
# Cluster : 133
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	validation_0-rmse:0.560269
#
# Score for this combination:  0.579942
# ('total time taken this loop: ', 0.9110000133514404)
# Cluster : 5
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	validation_0-rmse:0.624178
#
# Score for this combination:  0.647655
# ('total time taken this loop: ', 15.17199993133545)
# Cluster : 381
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.671902
#
# Score for this combination:  0.696465
# ('total time taken this loop: ', 7.948000192642212)
# Cluster : 52
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.622533
#
# Score for this combination:  0.648965
# ('total time taken this loop: ', 8.721999883651733)
# Cluster : 207
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.719156
#
# Score for this combination:  0.750074
# ('total time taken this loop: ', 7.797000169754028)
# Cluster : 152
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.791416
#
# Score for this combination:  0.827531
# ('total time taken this loop: ', 7.06499981880188)
# Cluster : 248
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.575368
#
# Score for this combination:  0.59336
# ('total time taken this loop: ', 6.06000018119812)
# Cluster : 230
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	validation_0-rmse:0.642079
#
# Score for this combination:  0.66627
# ('total time taken this loop: ', 13.546000003814697)
# Cluster : 210
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.55471
#
# Score for this combination:  0.584084
# ('total time taken this loop: ', 3.9079999923706055)
# Cluster : 379
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.610147
#
# Score for this combination:  0.645161
# ('total time taken this loop: ', 4.03600001335144)
# Cluster : 223
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [3]	validation_0-rmse:0.70294
#
# Score for this combination:  0.795513
# ('total time taken this loop: ', 0.43199992179870605)
# Cluster : 330
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.617914
#
# Score for this combination:  0.64153
# ('total time taken this loop: ', 6.5940001010894775)
# Cluster : 117
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.600324
#
# Score for this combination:  0.677492
# ('total time taken this loop: ', 0.75)
# Cluster : 99
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.582927
#
# Score for this combination:  0.619687
# ('total time taken this loop: ', 2.5929999351501465)
# Cluster : 18
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.543977
#
# Score for this combination:  0.580015
# ('total time taken this loop: ', 1.1719999313354492)
# Cluster : 388
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.619201
#
# Score for this combination:  0.644169
# ('total time taken this loop: ', 9.092999935150146)
# Cluster : 107
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	validation_0-rmse:0.648381
#
# Score for this combination:  0.69613
# ('total time taken this loop: ', 2.5480000972747803)
# Cluster : 168
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	validation_0-rmse:0.61083
#
# Score for this combination:  0.634826
# ('total time taken this loop: ', 11.911999940872192)
# Cluster : 12
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.650177
#
# Score for this combination:  0.67798
# ('total time taken this loop: ', 7.478000164031982)
# Cluster : 395
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.545838
#
# Score for this combination:  0.56374
# ('total time taken this loop: ', 5.296999931335449)
# Cluster : 186
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.544759
#
# Score for this combination:  0.56462
# ('total time taken this loop: ', 2.8899998664855957)
# Cluster : 202
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.611347
#
# Score for this combination:  0.65155
# ('total time taken this loop: ', 1.2970001697540283)
# Cluster : 292
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.5718
#
# Score for this combination:  0.596276
# ('total time taken this loop: ', 4.2809998989105225)
# Cluster : 203
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.58374
#
# Score for this combination:  0.61044
# ('total time taken this loop: ', 5.062000036239624)
# Cluster : 8
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.562831
#
# Score for this combination:  0.601334
# ('total time taken this loop: ', 2.8289999961853027)
# Cluster : 323
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.590516
#
# Score for this combination:  0.619835
# ('total time taken this loop: ', 4.6559998989105225)
# Cluster : 302
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.571419
#
# Score for this combination:  0.60177
# ('total time taken this loop: ', 4.108999967575073)
# Cluster : 137
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.797739
#
# Score for this combination:  0.820797
# ('total time taken this loop: ', 4.265000104904175)
# Cluster : 76
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [0]	validation_0-rmse:0.649986
#
# Score for this combination:  0.769681
# ('total time taken this loop: ', 0.6419999599456787)
# Cluster : 72
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.586637
#
# Score for this combination:  0.603436
# ('total time taken this loop: ', 4.9679999351501465)
# Cluster : 228
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.580018
#
# Score for this combination:  0.603094
# ('total time taken this loop: ', 10.375)
# Cluster : 264
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.632875
#
# Score for this combination:  0.684062
# ('total time taken this loop: ', 0.6710000038146973)
# Cluster : 332
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	validation_0-rmse:0.686029
#
# Score for this combination:  0.708788
# ('total time taken this loop: ', 7.330000162124634)
# Cluster : 276
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	validation_0-rmse:0.59361
#
# Score for this combination:  0.615007
# ('total time taken this loop: ', 16.810999870300293)
# Cluster : 225
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.621127
#
# Score for this combination:  0.650537
# ('total time taken this loop: ', 7.240000009536743)
# Cluster : 65
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.573764
#
# Score for this combination:  0.611815
# ('total time taken this loop: ', 4.36899995803833)
# Cluster : 94
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [1]	validation_0-rmse:0.529483
#
# Score for this combination:  0.600105
# ('total time taken this loop: ', 0.937000036239624)
# Cluster : 278
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.545796
#
# Score for this combination:  0.569052
# ('total time taken this loop: ', 1.9850001335144043)
# Cluster : 271
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.58037
#
# Score for this combination:  0.608652
# ('total time taken this loop: ', 3.172999858856201)
# Cluster : 83
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	validation_0-rmse:0.696848
#
# Score for this combination:  0.722661
# ('total time taken this loop: ', 5.077000141143799)
# Cluster : 304
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.701643
#
# Score for this combination:  0.731307
# ('total time taken this loop: ', 5.766000032424927)
# Cluster : 254
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.603464
#
# Score for this combination:  0.625322
# ('total time taken this loop: ', 5.764999866485596)
# Cluster : 315
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.606539
#
# Score for this combination:  0.626462
# ('total time taken this loop: ', 8.235000133514404)
# Cluster : 205
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	validation_0-rmse:0.548453
#
# Score for this combination:  0.583912
# ('total time taken this loop: ', 2.7960000038146973)
# Cluster : 269
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	validation_0-rmse:0.634058
#
# Score for this combination:  0.659394
# ('total time taken this loop: ', 13.530999898910522)
# Cluster : 167
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [0]	validation_0-rmse:0.724479
#
# Score for this combination:  0.90928
# ('total time taken this loop: ', 0.4530000686645508)
# Cluster : 85
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.717288
#
# Score for this combination:  0.74622
# ('total time taken this loop: ', 2.296999931335449)
# Cluster : 119
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.609175
#
# Score for this combination:  0.635859
# ('total time taken this loop: ', 3.065999984741211)
# Cluster : 166
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.620196
#
# Score for this combination:  0.653688
# ('total time taken this loop: ', 8.714999914169312)
# Cluster : 245
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.628355
#
# Score for this combination:  0.652815
# ('total time taken this loop: ', 12.188000202178955)
# Cluster : 244
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.751818
#
# Score for this combination:  0.835973
# ('total time taken this loop: ', 1.303999900817871)
# Cluster : 46
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.606087
#
# Score for this combination:  0.642716
# ('total time taken this loop: ', 4.132999897003174)
# Cluster : 31
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.598007
#
# Score for this combination:  0.630174
# ('total time taken this loop: ', 3.6410000324249268)
# Cluster : 45
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.629774
#
# Score for this combination:  0.666781
# ('total time taken this loop: ', 6.796000003814697)
# Cluster : 283
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.650598
#
# Score for this combination:  0.680007
# ('total time taken this loop: ', 3.9850001335144043)
# Cluster : 180
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.532798
#
# Score for this combination:  0.570398
# ('total time taken this loop: ', 1.7089998722076416)
# Cluster : 120
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.528009
#
# Score for this combination:  0.5476
# ('total time taken this loop: ', 3.5410001277923584)
# Cluster : 43
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.621788
#
# Score for this combination:  0.646211
# ('total time taken this loop: ', 13.92199993133545)
# Cluster : 206
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.674939
#
# Score for this combination:  0.709627
# ('total time taken this loop: ', 15.82800006866455)
# Cluster : 259
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.63194
#
# Score for this combination:  0.66692
# ('total time taken this loop: ', 8.187000036239624)
# Cluster : 274
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.560485
#
# Score for this combination:  0.601501
# ('total time taken this loop: ', 1.0)
# Cluster : 325
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	validation_0-rmse:0.580903
#
# Score for this combination:  0.600087
# ('total time taken this loop: ', 0.6409997940063477)
# Cluster : 253
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.580383
#
# Score for this combination:  0.606804
# ('total time taken this loop: ', 5.187000036239624)
# Cluster : 42
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.547154
#
# Score for this combination:  0.579329
# ('total time taken this loop: ', 1.4279999732971191)
# Cluster : 6
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.612753
#
# Score for this combination:  0.642802
# ('total time taken this loop: ', 4.213000059127808)
# Cluster : 170
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	validation_0-rmse:0.565068
#
# Score for this combination:  0.595343
# ('total time taken this loop: ', 3.9049999713897705)
# Cluster : 232
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.554254
#
# Score for this combination:  0.593703
# ('total time taken this loop: ', 1.5499999523162842)
# Cluster : 221
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.585099
#
# Score for this combination:  0.611467
# ('total time taken this loop: ', 4.737000226974487)
# Cluster : 185
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.565836
#
# Score for this combination:  0.585832
# ('total time taken this loop: ', 1.8999998569488525)
# Cluster : 198
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.554669
#
# Score for this combination:  0.568603
# ('total time taken this loop: ', 3.9149999618530273)
# Cluster : 191
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.799405
#
# Score for this combination:  0.838887
# ('total time taken this loop: ', 1.7730000019073486)
# Cluster : 280
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.529631
#
# Score for this combination:  0.558925
# ('total time taken this loop: ', 1.8840000629425049)
# Cluster : 367
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.622351
#
# Score for this combination:  0.65289
# ('total time taken this loop: ', 4.897000074386597)
# Cluster : 16
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.612071
#
# Score for this combination:  0.629234
# ('total time taken this loop: ', 3.4539999961853027)
# Cluster : 250
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	validation_0-rmse:0.585508
#
# Score for this combination:  0.623864
# ('total time taken this loop: ', 4.358000040054321)
# Cluster : 290
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.615755
#
# Score for this combination:  0.640929
# ('total time taken this loop: ', 9.203999996185303)
# Cluster : 161
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.663549
#
# Score for this combination:  0.689734
# ('total time taken this loop: ', 6.375)
# Cluster : 22
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.64703
#
# Score for this combination:  0.688944
# ('total time taken this loop: ', 1.7649998664855957)
# Cluster : 392
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.613664
#
# Score for this combination:  0.638315
# ('total time taken this loop: ', 6.413000106811523)
# Cluster : 380
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.640725
#
# Score for this combination:  0.671907
# ('total time taken this loop: ', 7.1499998569488525)
# Cluster : 96
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.555549
#
# Score for this combination:  0.569819
# ('total time taken this loop: ', 5.140000104904175)
# Cluster : 37
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.625438
#
# Score for this combination:  0.657325
# ('total time taken this loop: ', 5.358999967575073)
# Cluster : 124
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.571766
#
# Score for this combination:  0.593904
# ('total time taken this loop: ', 4.5940001010894775)
# Cluster : 148
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.614761
#
# Score for this combination:  0.649965
# ('total time taken this loop: ', 5.625)
# Cluster : 246
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.58397
#
# Score for this combination:  0.604377
# ('total time taken this loop: ', 9.562999963760376)
# Cluster : 214
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.567522
#
# Score for this combination:  0.592849
# ('total time taken this loop: ', 3.359999895095825)
# Cluster : 375
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.598036
#
# Score for this combination:  0.612625
# ('total time taken this loop: ', 10.342000007629395)
# Cluster : 131
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.428648
#
# Score for this combination:  0.442193
# ('total time taken this loop: ', 1.0320000648498535)
# Cluster : 319
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.600537
#
# Score for this combination:  0.625276
# ('total time taken this loop: ', 5.2809998989105225)
# Cluster : 172
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.665815
#
# Score for this combination:  0.702077
# ('total time taken this loop: ', 3.9230000972747803)
# Cluster : 122
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [28]	validation_0-rmse:0.802703
#
# Score for this combination:  0.814305
# ('total time taken this loop: ', 4.749000072479248)
# Cluster : 187
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.668073
#
# Score for this combination:  0.715276
# ('total time taken this loop: ', 1.1569998264312744)
# Cluster : 142
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [25]	validation_0-rmse:0.953125
#
# Score for this combination:  1.130792
# ('total time taken this loop: ', 0.5150001049041748)
# Cluster : 331
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.597609
#
# Score for this combination:  0.626356
# ('total time taken this loop: ', 4.4679999351501465)
# Cluster : 106
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [0]	validation_0-rmse:0.709395
#
# Score for this combination:  1.055933
# ('total time taken this loop: ', 0.4219999313354492)
# Cluster : 394
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.547686
#
# Score for this combination:  0.57661
# ('total time taken this loop: ', 2.17900013923645)
# Cluster : 11
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.585978
#
# Score for this combination:  0.619161
# ('total time taken this loop: ', 3.7019999027252197)
# Cluster : 362
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.528332
#
# Score for this combination:  0.553149
# ('total time taken this loop: ', 2.697000026702881)
# Cluster : 377
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.483784
#
# Score for this combination:  0.505036
# ('total time taken this loop: ', 1.5160000324249268)
# Cluster : 312
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [2]	validation_0-rmse:0.67095
#
# Score for this combination:  0.753776
# ('total time taken this loop: ', 0.5929999351501465)
# Cluster : 189
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.56757
#
# Score for this combination:  0.594828
# ('total time taken this loop: ', 3.328000068664551)
# Cluster : 389
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.573097
#
# Score for this combination:  0.592903
# ('total time taken this loop: ', 4.5940001010894775)
# Cluster : 174
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.670233
#
# Score for this combination:  0.708262
# ('total time taken this loop: ', 2.9539999961853027)
# Cluster : 14
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.590551
#
# Score for this combination:  0.617612
# ('total time taken this loop: ', 2.8899998664855957)
# Cluster : 298
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.626476
#
# Score for this combination:  0.658738
# ('total time taken this loop: ', 3.078000068664551)
# Cluster : 92
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.597587
#
# Score for this combination:  0.619692
# ('total time taken this loop: ', 3.297999858856201)
# Cluster : 44
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	validation_0-rmse:0.608396
#
# Score for this combination:  0.6276
# ('total time taken this loop: ', 12.187000036239624)
# Cluster : 369
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.661899
#
# Score for this combination:  0.70338
# ('total time taken this loop: ', 3.875)
# Cluster : 252
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	validation_0-rmse:0.651386
#
# Score for this combination:  0.700937
# ('total time taken this loop: ', 2.453000068664551)
# Cluster : 103
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.61409
#
# Score for this combination:  0.668939
# ('total time taken this loop: ', 1.4210000038146973)
# Cluster : 306
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.642402
#
# Score for this combination:  0.664688
# ('total time taken this loop: ', 8.719000101089478)
# Cluster : 108
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.645277
#
# Score for this combination:  0.680296
# ('total time taken this loop: ', 3.6559998989105225)
# Cluster : 277
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.592993
#
# Score for this combination:  0.617688
# ('total time taken this loop: ', 5.765000104904175)
# Cluster : 349
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [2]	validation_0-rmse:0.657242
#
# Score for this combination:  0.7585
# ('total time taken this loop: ', 0.8280000686645508)
# Cluster : 194
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.586481
#
# Score for this combination:  0.606047
# ('total time taken this loop: ', 9.469000101089478)
# Cluster : 371
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.592482
#
# Score for this combination:  0.610047
# ('total time taken this loop: ', 5.4059998989105225)
# Cluster : 338
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.609879
#
# Score for this combination:  0.637692
# ('total time taken this loop: ', 9.906000137329102)
# Cluster : 178
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.661204
#
# Score for this combination:  0.69387
# ('total time taken this loop: ', 2.444999933242798)
# Cluster : 192
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.797552
#
# Score for this combination:  0.831075
# ('total time taken this loop: ', 2.4019999504089355)
# Cluster : 63
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.77036
#
# Score for this combination:  0.798245
# ('total time taken this loop: ', 2.549999952316284)
# Cluster : 155
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.636129
#
# Score for this combination:  0.669013
# ('total time taken this loop: ', 6.666000127792358)
# Cluster : 101
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.490724
#
# Score for this combination:  0.502562
# ('total time taken this loop: ', 2.0769999027252197)
# Cluster : 151
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.629555
#
# Score for this combination:  0.647792
# ('total time taken this loop: ', 8.125999927520752)
# Cluster : 216
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.571926
#
# Score for this combination:  0.589965
# ('total time taken this loop: ', 4.073000192642212)
# Cluster : 231
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.766372
#
# Score for this combination:  0.813223
# ('total time taken this loop: ', 4.021999835968018)
# Cluster : 25
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [1]	validation_0-rmse:0.742094
#
# Score for this combination:  0.867147
# ('total time taken this loop: ', 0.5600001811981201)
# Cluster : 209
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.627295
#
# Score for this combination:  0.662669
# ('total time taken this loop: ', 6.84499979019165)
# Cluster : 88
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	validation_0-rmse:0.605909
#
# Score for this combination:  0.643547
# ('total time taken this loop: ', 2.0310001373291016)
# Cluster : 316
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.662381
#
# Score for this combination:  0.707043
# ('total time taken this loop: ', 1.0929999351501465)
# Cluster : 258
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [3]	validation_0-rmse:1.09797
#
# Score for this combination:  1.275468
# ('total time taken this loop: ', 0.5789999961853027)
# Cluster : 224
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.593409
#
# Score for this combination:  0.615115
# ('total time taken this loop: ', 4.115000009536743)
# Cluster : 116
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.614121
#
# Score for this combination:  0.647269
# ('total time taken this loop: ', 3.993000030517578)
# Cluster : 345
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.605223
#
# Score for this combination:  0.627674
# ('total time taken this loop: ', 10.469000101089478)
# Cluster : 293
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.61964
#
# Score for this combination:  0.638067
# ('total time taken this loop: ', 3.4069998264312744)
# Cluster : 352
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.640601
#
# Score for this combination:  0.669914
# ('total time taken this loop: ', 4.686000108718872)
# Cluster : 234
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.559055
#
# Score for this combination:  0.576284
# ('total time taken this loop: ', 3.6579999923706055)
# Cluster : 270
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.860569
#
# Score for this combination:  0.974762
# ('total time taken this loop: ', 0.4530000686645508)
# Cluster : 55
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.507968
#
# Score for this combination:  0.538607
# ('total time taken this loop: ', 0.7179999351501465)
# Cluster : 219
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.756924
#
# Score for this combination:  0.810634
# ('total time taken this loop: ', 2.046999931335449)
# Cluster : 89
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.583385
#
# Score for this combination:  0.611077
# ('total time taken this loop: ', 1.812000036239624)
# Cluster : 364
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.625256
#
# Score for this combination:  0.657125
# ('total time taken this loop: ', 7.687000036239624)
# Cluster : 135
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.525755
#
# Score for this combination:  0.560811
# ('total time taken this loop: ', 1.1329998970031738)
# Cluster : 53
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [3]	validation_0-rmse:0.562866
#
# Score for this combination:  0.622441
# ('total time taken this loop: ', 1.7430000305175781)
# Cluster : 261
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	validation_0-rmse:0.773526
#
# Score for this combination:  0.804579
# ('total time taken this loop: ', 4.906000137329102)
# Cluster : 263
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.662245
#
# Score for this combination:  0.698096
# ('total time taken this loop: ', 5.421999931335449)
# Cluster : 90
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.806295
#
# Score for this combination:  0.859728
# ('total time taken this loop: ', 0.873999834060669)
# Cluster : 354
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.621588
#
# Score for this combination:  0.634895
# ('total time taken this loop: ', 4.813000202178955)
# Cluster : 370
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	validation_0-rmse:0.570564
#
# Score for this combination:  0.605666
# ('total time taken this loop: ', 2.069999933242798)
# Cluster : 163
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.708453
#
# Score for this combination:  0.748585
# ('total time taken this loop: ', 4.894000053405762)
# Cluster : 297
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.704554
#
# Score for this combination:  0.777092
# ('total time taken this loop: ', 1.613999843597412)
# Cluster : 294
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [2]	validation_0-rmse:0.817636
#
# Score for this combination:  0.95663
# ('total time taken this loop: ', 0.5940001010894775)
# Cluster : 350
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.411876
#
# Score for this combination:  0.424838
# ('total time taken this loop: ', 0.9219999313354492)
# Cluster : 242
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.594475
#
# Score for this combination:  0.617531
# ('total time taken this loop: ', 3.640000104904175)
# Cluster : 164
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.58439
#
# Score for this combination:  0.621827
# ('total time taken this loop: ', 3.2719998359680176)
# Cluster : 134
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	validation_0-rmse:0.630343
#
# Score for this combination:  0.660854
# ('total time taken this loop: ', 12.041000127792358)
# Cluster : 193
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.616522
#
# Score for this combination:  0.659032
# ('total time taken this loop: ', 2.6559998989105225)
# Cluster : 286
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	validation_0-rmse:0.554325
#
# Score for this combination:  0.59409
# ('total time taken this loop: ', 1.8280000686645508)
# Cluster : 305
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [0]	validation_0-rmse:0.632339
#
# Score for this combination:  0.774538
# ('total time taken this loop: ', 0.42100000381469727)
# Cluster : 15
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [1]	validation_0-rmse:0.871091
#
# Score for this combination:  1.00738
# ('total time taken this loop: ', 0.564000129699707)
# Cluster : 247
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.487884
#
# Score for this combination:  0.503628
# ('total time taken this loop: ', 2.4749999046325684)
# Cluster : 272
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.543078
#
# Score for this combination:  0.562066
# ('total time taken this loop: ', 2.5859999656677246)
# Cluster : 156
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [16]	validation_0-rmse:0.745376
#
# Score for this combination:  0.777035
# ('total time taken this loop: ', 3.984999895095825)
# Cluster : 184
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.664065
#
# Score for this combination:  0.695714
# ('total time taken this loop: ', 7.368000030517578)
# Cluster : 282
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.646488
#
# Score for this combination:  0.66289
# ('total time taken this loop: ', 1.5850000381469727)
# Cluster : 98
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.641144
#
# Score for this combination:  0.707304
# ('total time taken this loop: ', 0.7810001373291016)
# Cluster : 159
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.616459
#
# Score for this combination:  0.641588
# ('total time taken this loop: ', 5.3450000286102295)
# Cluster : 160
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.62147
#
# Score for this combination:  0.659351
# ('total time taken this loop: ', 5.436999797821045)
# Cluster : 360
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.707236
#
# Score for this combination:  0.736538
# ('total time taken this loop: ', 7.437000036239624)
# Cluster : 54
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [3]	validation_0-rmse:0.681334
#
# Score for this combination:  0.755238
# ('total time taken this loop: ', 1.625)
# Cluster : 238
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.664121
#
# Score for this combination:  0.694319
# ('total time taken this loop: ', 3.5460000038146973)
# Cluster : 23
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	validation_0-rmse:0.695094
#
# Score for this combination:  0.72422
# ('total time taken this loop: ', 8.875999927520752)
# Cluster : 150
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.565452
#
# Score for this combination:  0.587967
# ('total time taken this loop: ', 3.687000036239624)
# Cluster : 21
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.634439
#
# Score for this combination:  0.66132
# ('total time taken this loop: ', 8.625)
# Cluster : 327
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.60027
#
# Score for this combination:  0.624483
# ('total time taken this loop: ', 6.0)
# Cluster : 2
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.835404
#
# Score for this combination:  0.890572
# ('total time taken this loop: ', 1.8900001049041748)
# Cluster : 396
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.557376
#
# Score for this combination:  0.576687
# ('total time taken this loop: ', 2.984999895095825)
# Cluster : 162
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	validation_0-rmse:0.777857
#
# Score for this combination:  0.844784
# ('total time taken this loop: ', 1.812000036239624)
# Cluster : 299
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.768744
#
# Score for this combination:  0.811154
# ('total time taken this loop: ', 1.7090001106262207)
# Cluster : 241
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.671166
#
# Score for this combination:  0.681794
# ('total time taken this loop: ', 3.010999917984009)
# Cluster : 378
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.548334
#
# Score for this combination:  0.575908
# ('total time taken this loop: ', 2.1510000228881836)
# Cluster : 281
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.488935
#
# Score for this combination:  0.521218
# ('total time taken this loop: ', 0.9570000171661377)
# Cluster : 173
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [5]	validation_0-rmse:0.555474
#
# Score for this combination:  0.589468
# ('total time taken this loop: ', 2.4689998626708984)
# Cluster : 158
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.582835
#
# Score for this combination:  0.598245
# ('total time taken this loop: ', 3.9690001010894775)
# Cluster : 348
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.57986
#
# Score for this combination:  0.60928
# ('total time taken this loop: ', 2.828000068664551)
# Cluster : 34
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [2]	validation_0-rmse:0.529066
#
# Score for this combination:  0.583482
# ('total time taken this loop: ', 1.0149998664855957)
# Cluster : 303
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	validation_0-rmse:0.673341
#
# Score for this combination:  0.698578
# ('total time taken this loop: ', 3.5380001068115234)
# Cluster : 343
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.366162
#
# Score for this combination:  0.374471
# ('total time taken this loop: ', 0.5720000267028809)
# Cluster : 384
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [8]	validation_0-rmse:0.569445
#
# Score for this combination:  0.599022
# ('total time taken this loop: ', 2.437000036239624)
# Cluster : 113
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [0]	validation_0-rmse:0.737646
#
# Score for this combination:  0.871499
# ('total time taken this loop: ', 0.6559998989105225)
# Cluster : 13
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	validation_0-rmse:0.554981
#
# Score for this combination:  0.569578
# ('total time taken this loop: ', 5.437000036239624)
# Cluster : 376
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.636944
#
# Score for this combination:  0.662253
# ('total time taken this loop: ', 9.687999963760376)
# Cluster : 68
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.575051
#
# Score for this combination:  0.598591
# ('total time taken this loop: ', 4.7809998989105225)
# Cluster : 28
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.639944
#
# Score for this combination:  0.671856
# ('total time taken this loop: ', 0.6600000858306885)
# Cluster : 357
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.617862
#
# Score for this combination:  0.657055
# ('total time taken this loop: ', 3.2309999465942383)
# Cluster : 77
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.513152
#
# Score for this combination:  0.542282
# ('total time taken this loop: ', 1.0)
# Cluster : 136
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# ...
# ('total time taken this loop: ', 0.6710000038146973)
# Cluster : 249
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.797309
#
# Score for this combination:  0.819352
# ('total time taken this loop: ', 0.5529999732971191)
# Cluster : 201
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [18]	validation_0-rmse:0.557977
#
# Score for this combination:  0.560876
# ('total time taken this loop: ', 0.9480001926422119)
# Cluster : 102
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.890721
#
# Score for this combination:  0.981306
# ('total time taken this loop: ', 0.623999834060669)
# Cluster : 341
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [17]	validation_0-rmse:0.717091
#
# Score for this combination:  0.739127
# ('total time taken this loop: ', 4.453000068664551)
# Cluster : 301
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	validation_0-rmse:1.0232
#
# Score for this combination:  1.079066
# ('total time taken this loop: ', 1.9530000686645508)
# Cluster : 59
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [19]	validation_0-rmse:0.864355
#
# Score for this combination:  0.887661
# ('total time taken this loop: ', 0.8919999599456787)
# Cluster : 30
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [14]	validation_0-rmse:0.68869
#
# Score for this combination:  0.716809
# ('total time taken this loop: ', 6.098999977111816)
# Cluster : 398
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [3]	validation_0-rmse:0.729514
#
# Score for this combination:  0.83297
# ('total time taken this loop: ', 1.0720000267028809)
# Cluster : 356
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	validation_0-rmse:0.681191
#
# Score for this combination:  0.708056
# ('total time taken this loop: ', 2.8429999351501465)
# Cluster : 114
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [47]	validation_0-rmse:0.565402
#
# Score for this combination:  0.578376
# ('total time taken this loop: ', 6.42300009727478)
# Cluster : 291
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:1.18045
#
# Score for this combination:  1.326187
# ('total time taken this loop: ', 0.4200000762939453)
# Cluster : 363
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [37]	validation_0-rmse:0.585703
#
# Score for this combination:  0.599345
# ('total time taken this loop: ', 0.500999927520752)
# Cluster : 4
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [17]	validation_0-rmse:0.833825
#
# Score for this combination:  0.870712
# ('total time taken this loop: ', 2.687999963760376)
# Cluster : 289
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	validation_0-rmse:0.696287
#
# Score for this combination:  0.729086
# ('total time taken this loop: ', 8.265000104904175)
# Cluster : 190
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [21]	validation_0-rmse:1.00159
#
# Score for this combination:  1.026918
# ('total time taken this loop: ', 0.625)
# Cluster : 56
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [25]	validation_0-rmse:0.720053
#
# Score for this combination:  0.729413
# ('total time taken this loop: ', 3.2029998302459717)
# Cluster : 211
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [7]	validation_0-rmse:0.76939
#
# Score for this combination:  0.830744
# ('total time taken this loop: ', 1.0)
# Cluster : 112
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [0]	validation_0-rmse:0.245779
#
# Score for this combination:  0.379123
# ('total time taken this loop: ', 0.32899999618530273)
# Cluster : 115
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [18]	validation_0-rmse:0.673123
#
# Score for this combination:  0.690123
# ('total time taken this loop: ', 1.4680001735687256)
# Cluster : 62
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [3]	validation_0-rmse:0.725922
#
# Score for this combination:  0.794154
# ('total time taken this loop: ', 0.5779998302459717)
# Cluster : 129
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [0]	validation_0-rmse:0.700757
#
# Score for this combination:  0.89018
# ('total time taken this loop: ', 0.42799997329711914)
# Cluster : 310
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.536007
#
# Score for this combination:  0.577541
# ('total time taken this loop: ', 0.5880000591278076)
# Cluster : 32
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [17]	validation_0-rmse:1.16832
#
# Score for this combination:  1.177181
# ('total time taken this loop: ', 0.4590001106262207)
# Cluster : 397
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [1]	validation_0-rmse:0.59401
#
# Score for this combination:  0.649976
# ('total time taken this loop: ', 0.44700002670288086)
# Cluster : 196
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [21]	validation_0-rmse:0.711544
#
# Score for this combination:  0.747623
# ('total time taken this loop: ', 1.1409997940063477)
# Cluster : 91
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	validation_0-rmse:0.79706
#
# Score for this combination:  0.826884
# ('total time taken this loop: ', 0.8440001010894775)
# Cluster : 39
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [38]	validation_0-rmse:0.390284
#
# Score for this combination:  0.403444
# ('total time taken this loop: ', 0.874000072479248)
# Cluster : 123
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.645008
#
# Score for this combination:  0.667745
# ('total time taken this loop: ', 4.7809998989105225)
# Cluster : 74
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [22]	validation_0-rmse:0.601259
#
# Score for this combination:  0.617096
# ('total time taken this loop: ', 0.8320000171661377)
# Cluster : 226
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [18]	validation_0-rmse:1.16273
#
# Score for this combination:  1.176066
# ('total time taken this loop: ', 0.6410000324249268)
# Cluster : 132
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [16]	validation_0-rmse:0.848999
#
# Score for this combination:  0.885863
# ('total time taken this loop: ', 2.450000047683716)
# Cluster : 311
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.942117
#
# Score for this combination:  0.968922
# ('total time taken this loop: ', 1.9279999732971191)
# Cluster : 84
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.845659
#
# Score for this combination:  0.885233
# ('total time taken this loop: ', 0.7590000629425049)
# Cluster : 145
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [83]	validation_0-rmse:0.00199
#
# Score for this combination:  0.043494
# ('total time taken this loop: ', 0.7339999675750732)
# Cluster : 81
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.717423
#
# Score for this combination:  0.784305
# ('total time taken this loop: ', 0.5939998626708984)
# Cluster : 36
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [19]	validation_0-rmse:0.942139
#
# Score for this combination:  0.9733
# ('total time taken this loop: ', 1.6400001049041748)
# Cluster : 138
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [29]	validation_0-rmse:0.006102
#
# Score for this combination:  0.15978
# ('total time taken this loop: ', 0.39100003242492676)
# Cluster : 78
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.740177
#
# Score for this combination:  0.779796
# ('total time taken this loop: ', 0.9900000095367432)
# Cluster : 153
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [58]	validation_0-rmse:0.262578
#
# Score for this combination:  0.273491
# ('total time taken this loop: ', 0.931999921798706)
# Cluster : 75
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.706382
#
# Score for this combination:  0.775977
# ('total time taken this loop: ', 0.7660000324249268)
# Cluster : 67
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.996258
#
# Score for this combination:  1.09968
# ('total time taken this loop: ', 0.4679999351501465)
# Cluster : 355
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:0.699944
#
# Score for this combination:  0.710973
# ('total time taken this loop: ', 2.006999969482422)
# Cluster : 35
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [18]	validation_0-rmse:0.732815
#
# Score for this combination:  0.784274
# ('total time taken this loop: ', 0.5710000991821289)
# Cluster : 10
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [6]	validation_0-rmse:0.909837
#
# Score for this combination:  1.00461
# ('total time taken this loop: ', 0.5709998607635498)
# Cluster : 383
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [26]	validation_0-rmse:0.804916
#
# Score for this combination:  0.8201
# ('total time taken this loop: ', 2.5380001068115234)
# Cluster : 399
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [13]	validation_0-rmse:1.11274
#
# Score for this combination:  1.197198
# ('total time taken this loop: ', 0.45399999618530273)
# Cluster : 69
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [12]	validation_0-rmse:0.811217
#
# Score for this combination:  0.840245
# ('total time taken this loop: ', 0.75)
# Cluster : 251
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [15]	validation_0-rmse:1.06927
#
# Score for this combination:  1.107532
# ('total time taken this loop: ', 0.6089999675750732)
# Cluster : 275
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.724138
#
# Score for this combination:  0.79524
# ('total time taken this loop: ', 0.41300010681152344)
# Cluster : 188
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [19]	validation_0-rmse:0.755768
#
# Score for this combination:  0.767172
# ('total time taken this loop: ', 0.5869998931884766)
# Cluster : 26
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.875485
#
# Score for this combination:  0.94246
# ('total time taken this loop: ', 1.0940001010894775)
# Cluster : 127
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [11]	validation_0-rmse:0.921088
#
# Score for this combination:  0.955735
# ('total time taken this loop: ', 1.0319998264312744)
# Cluster : 208
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [4]	validation_0-rmse:0.605186
#
# Score for this combination:  0.682445
# ('total time taken this loop: ', 0.49900007247924805)
# Cluster : 334
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [16]	validation_0-rmse:0.739082
#
# Score for this combination:  0.761382
# ('total time taken this loop: ', 1.0789999961853027)
# Cluster : 313
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation_0-rmse:0.778194
#
# Score for this combination:  0.820761
# ('total time taken this loop: ', 1.6089999675750732)
# Cluster : 260
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [21]	validation_0-rmse:0.20254
#
# Score for this combination:  0.241764
# ('total time taken this loop: ', 0.4680001735687256)
# Cluster : 100
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [24]	validation_0-rmse:1.05175
#
# Score for this combination:  1.085978
# ('total time taken this loop: ', 1.8599998950958252)
# Cluster : 175
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [0]	validation_0-rmse:0.714655
#
# Score for this combination:  0.990747
# ('total time taken this loop: ', 0.437999963760376)
# Cluster : 279
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [10]	validation_0-rmse:0.863176
#
# Score for this combination:  0.920953
# ('total time taken this loop: ', 1.0299999713897705)
# Cluster : 141
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-14-3e449c04aa1a> in <module>()
#      19
#      20         grid_gbm = xgb.XGBRegressor(**g)
# ---> 21         grid_gbm.fit(x_train, y_train,eval_set=[(x_valid,y_valid)] ,eval_metric='rmse',verbose='False',early_stopping_rounds=10)
#      22
#      23         score = grid_gbm.evals_result_.values()[-1].values()[-1][-1]
#
# C:\Anaconda\lib\site-packages\xgboost-0.4-py2.7.egg\xgboost\sklearn.pyc in fit(self, X, y, eval_set, eval_metric, early_stopping_rounds, verbose)
#     249                               early_stopping_rounds=early_stopping_rounds,
#     250                               evals_result=evals_result, obj=obj, feval=feval,
# --> 251                               verbose_eval=verbose)
#     252
#     253         if evals_result:
#
# C:\Anaconda\lib\site-packages\xgboost-0.4-py2.7.egg\xgboost\training.pyc in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, learning_rates, xgb_model, callbacks)
#     203                            evals=evals,
#     204                            obj=obj, feval=feval,
# --> 205                            xgb_model=xgb_model, callbacks=callbacks)
#     206
#     207
#
# C:\Anaconda\lib\site-packages\xgboost-0.4-py2.7.egg\xgboost\training.pyc in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      84         # check evaluation result.
#      85         if len(evals) != 0:
# ---> 86             bst_eval_set = bst.eval_set(evals, i, feval)
#      87             if isinstance(bst_eval_set, STRING_TYPES):
#      88                 msg = bst_eval_set
#
# C:\Anaconda\lib\site-packages\xgboost-0.4-py2.7.egg\xgboost\core.pyc in eval_set(self, evals, iteration, feval)
#     865             _check_call(_LIB.XGBoosterEvalOneIter(self.handle, iteration,
#     866                                                   dmats, evnames, len(evals),
# --> 867                                                   ctypes.byref(msg)))
#     868             return msg.value
#     869         else:
#
# C:\Anaconda\lib\site-packages\xgboost-0.4-py2.7.egg\xgboost\core.pyc in _check_call(ret)
#     125     """
#     126     if ret != 0:
# --> 127         raise XGBoostError(_LIB.XGBGetLastError())
#     128
#     129
#
# XGBoostError: [03:47:37] src/metric/elementwise_metric.cc:27: Check failed: (info.labels.size()) != (0) label set cannot be empty

# %%
print "Total Sick Clusters :", len(sick_clusters)

# %%
import seaborn as sns


sns.distplot(df_train.Cliente_ID_clust_ID.fillna(-999))

# %% [markdown]
# I like that the 400 clusters are somewhat of uniform distribution

# %%
print "R2 Validation= ",r2_score(np.float64(val_pred.target),np.float64(val_pred.pred))
print "RMSE Validation ", np.sqrt(mean_squared_error(val_pred.target,np.float64(val_pred.pred)))

# %%
df_sick = pd.DataFrame(sick_clusters, columns=['ClusID','RMSE'])

# %%
print 100* np.float(X_train[X_train.Cliente_ID_clust_ID.isin(df_sick.ClusID)].shape[0]) / X_train.shape[0]

# %% [markdown]
# Let's train using all the sick clusters:

# %%
sick_val_pred = pd.DataFrame()

    

for g in ParameterGrid(best_param):
    start = time.time()
        
    x_train = X_train[X_train.Cliente_ID_clust_ID.isin(df_sick.ClusID)]
    y_train = df_train['Demanda_uni_equil'][df_train.Cliente_ID_clust_ID.isin(df_sick.ClusID)]
        
    x_valid = X_valid[X_valid.Cliente_ID_clust_ID.isin(df_sick.ClusID)]
    y_valid = df_validation['Demanda_uni_equil'][df_validation.Cliente_ID_clust_ID.isin(df_sick.ClusID)]

    sick_gbm = xgb.XGBRegressor(**g)
    sick_gbm.fit(x_train, y_train,eval_set=[(x_valid,y_valid)] ,eval_metric='rmse',verbose='True',early_stopping_rounds=10)
        
    score = sick_gbm.evals_result_.values()[-1].values()[-1][-1]
    print "Score for this combination: ", score
        
    tmp = pd.DataFrame()
    tmp['target'] = y_valid
    tmp['pred'] =  sick_gbm.predict(x_valid)
    tmp['cluster'] = df_train.Cliente_ID_clust_ID
    sick_val_pred =pd.concat([sick_val_pred,tmp], ignore_index=True)
        
    print("total time taken this loop: ", time.time() - start)

    #pred_train = gbm.predict(X_train)
    #pred_val = gbm.predict(X_valid)

    #print "R2 Train = ",r2_score(np.float64(Y_train),np.float64(pred_train))
    #print "RMSE Train", np.sqrt(mean_squared_error(np.float64(Y_train),np.float64(pred_train)))
    
    #print "R2 Validation= ",r2_score(np.float64(Y_valid),np.float64(pred_val))
    #print "RMSE Validation ", np.sqrt(mean_squared_error(np.float64(Y_valid),np.float64(pred_val)))

# %%
good_pred = val_pred[~val_pred.cluster.isin(sick_clusters)]
total_pred = pd.concat([good_pred, sick_val_pred], ignore_index=True)
print "R2 Validation= ",r2_score(np.float64(total_pred.target),np.float64(total_pred.pred))
print "RMSE Validation ", np.sqrt(mean_squared_error(total_pred.target,np.float64(total_pred.pred)))

# %%
print "R2 Validation= ",r2_score(np.float64(good_pred.target),np.float64(good_pred.pred))
print "RMSE Validation ", np.sqrt(mean_squared_error(good_pred.target,np.float64(good_pred.pred)))

print "R2 Validation= ",r2_score(np.float64(sick_val_pred.target),np.float64(sick_val_pred.pred))
print "RMSE Validation ", np.sqrt(mean_squared_error(sick_val_pred.target,np.float64(sick_val_pred.pred)))

# %%
df_all = df_train.append(df_validation, ignore_index=True)

X = df_all[features]
Y = df_all['Demanda_uni_equil']

# %%
good_clusters = np.setdiff1d(clusters_by_ClientDemand.Cliente_ID_clust_ID.unique(),df_sick.ClusID)

val_pred = pd.DataFrame()


from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.grid_search import ParameterGrid

for cluster in clusters_by_ClientDemand.Cliente_ID_clust_ID.unique():

    for g in ParameterGrid(best_param):
        start = time.time()
        

        x = X
        y = df_all['Demanda_uni_equil']

        gbm = xgb.XGBRegressor(**g)
        print y.shape
        display(y.head())
        display(x.head())
        print x.shape
        gbm.fit(x, y ,eval_metric='rmse',early_stopping_rounds=10)


        print("total time taken this loop: ", time.time() - start)

    tmp = pd.DataFrame()
    tmp['target'] = y
    tmp['pred'] =  gbm.predict(x)
    tmp['cluster'] = X.Cliente_ID_clust_ID
    val_pred =pd.concat([val_pred,tmp], ignore_index=True)
    
    pred = gbm.predict(x)

    print "R2 = ",r2_score(np.float64(y),np.float64(pred))
    print "RMSE", np.sqrt(mean_squared_error(np.float64(y),np.float64(pred)))

# %%
sick_val_pred = pd.DataFrame()

for g in ParameterGrid(best_param):
    start = time.time()
        
    x = X[X.Cliente_ID_clust_ID.isin(df_sick.ClusID)]
    y = df_all['Demanda_uni_equil'][df_.Cliente_ID_clust_ID.isin(df_sick.ClusID)]
        
    
    sick_gbm = xgb.XGBRegressor(**g)
    sick_gbm.fit(x, y ,eval_metric='rmse',verbose='True',early_stopping_rounds=10)
        
    score = sick_gbm.evals_result_.values()[-1].values()[-1][-1]
    print "Score for this combination: ", score
        
    tmp = pd.DataFrame()
    tmp['target'] = y
    tmp['pred'] =  sick_gbm.predict(x)
    tmp['cluster'] = x.Cliente_ID_clust_ID
    sick_val_pred =pd.concat([sick_val_pred,tmp], ignore_index=True)
        
    print("total time taken this loop: ", time.time() - start)
    
    pred = gbm.predict(x)

    print "R2 = ",r2_score(np.float64(y),np.float64(pred))
    print "RMSE", np.sqrt(mean_squared_error(np.float64(y),np.float64(pred)))
